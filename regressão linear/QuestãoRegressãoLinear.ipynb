# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
from yellowbrick.regressor import ResidualsPlot

# %%
df = pd.read_csv('slr12.csv')
column = df['FrqAnual;CusInic'].values
df

# %%
#Tratando os dados da tabela
freq = []
cust = []
for i in column:
    new_array = i.split(';') #Generate a new array
    freq.append(int(new_array[0]))
    cust.append(int(new_array[1]))

# %%
df['TaxaAnual'] = freq
df['CustoInicial'] = cust
df.drop(columns='FrqAnual;CusInic', inplace=True)

# %%
df

# %%
X = df['TaxaAnual'].values
Y = df['CustoInicial'].values
X = X.reshape(-1,1)
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
results = model.predict([[1300]])

# %%
plt.scatter(X,Y)
plt.plot(X, modelo.predict(X))

# %%
plot = ResidualsPlot(modelo)
plot.fit(X,Y)
plot.show()
# Out:
# <Axes: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>
